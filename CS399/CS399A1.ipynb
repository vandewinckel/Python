# %%
# -*- coding: utf-8 -*-
"""
Spyder Editor

This is a temporary script file.
"""

c1 = input("Team 1: ")
man_t1 = input("Enter Manager for Team 1: ")
sub1_t1 = input("Enter Substitute 1 for Team 1: ")
sub2_t1 = input("Enter Substitute 2 for Team 1: ")
sub3_t1 = input("Enter Substitute 3 for Team 1: ")
sub4_t1 = input("Enter Substitute 4 for Team 1: ")
sub5_t1 = input("Enter Substitute 5 for Team 1: ")
sub6_t1 = input("Enter Substitute 6 for Team 1: ")
sub7_t1 = input("Enter Substitute 7 for Team 1: ")
form_t1 = input("Enter Formation; 1343 or 1442 : ")

#Team 1 Players 10

p1_t1_n = input("Enter Name for Player 1 on " + c1 + ":")
p1_t1_p = input("Enter Position for " + p1_t1_n +":")
p1_t1_c = input("Enter Country for " + p1_t1_n + ":")
p1_t1_j = input("Enter Jersey Number for " + p1_t1_n + ":")

p2_t1_n = input("Enter Name for Player 2 on " + c1 + ":")
p2_t1_p = input("Enter Position for " + p2_t1_n +":")
p2_t1_c = input("Enter Country for " + p2_t1_n + ":")
p2_t1_j = input("Enter Jersey Number for " + p2_t1_n + ":")

p3_t1_n = input("Enter Name for Player 3 on " + c1 + ":")
p3_t1_p = input("Enter Position for " + p3_t1_n +":")
p3_t1_c = input("Enter Country for " + p3_t1_n + ":")
p3_t1_j = input("Enter Jersey Number for " + p3_t1_n + ":")

p4_t1_n = input("Enter Name for Player 4 on " + c1 + ":")
p4_t1_p = input("Enter Position for " + p4_t1_n +":")
p4_t1_c = input("Enter Country for " + p4_t1_n + ":")
p4_t1_j = input("Enter Jersey Number for " + p4_t1_n + ":")

p5_t1_n = input("Enter Name for Player 5 on " + c1 + ":")
p5_t1_p = input("Enter Position for " + p5_t1_n +":")
p5_t1_c = input("Enter Country for " + p5_t1_n + ":")
p5_t1_j = input("Enter Jersey Number for " + p5_t1_n + ":")

p6_t1_n = input("Enter Name for Player 6 on " + c1 + ":")
p6_t1_p = input("Enter Position for " + p6_t1_n +":")
p6_t1_c = input("Enter Country for " + p6_t1_n + ":")
p6_t1_j = input("Enter Jersey Number for " + p6_t1_n + ":")

p7_t1_n = input("Enter Name for Player 7 on " + c1 + ":")
p7_t1_p = input("Enter Position for " + p7_t1_n +":")
p7_t1_c = input("Enter Country for " + p7_t1_n + ":")
p7_t1_j = input("Enter Jersey Number for " + p7_t1_n + ":")

p8_t1_n = input("Enter Name for Player 8 on " + c1 + ":")
p8_t1_p = input("Enter Position for " + p8_t1_n +":")
p8_t1_c = input("Enter Country for " + p8_t1_n + ":")
p8_t1_j = input("Enter Jersey Number for " + p8_t1_n + ":")

p9_t1_n = input("Enter Name for Player 9 on " + c1 + ":")
p9_t1_p = input("Enter Position for " + p9_t1_n +":")
p9_t1_c = input("Enter Country for " + p9_t1_n + ":")
p9_t1_j = input("Enter Jersey Number for " + p9_t1_n + ":")

p10_t1_n = input("Enter Name for Player 10 on " + c1 + ":")
p10_t1_p = input("Enter Position for " + p10_t1_n +":")
p10_t1_c = input("Enter Country for " + p10_t1_n + ":")
p10_t1_j = input("Enter Jersey Number for " + p10_t1_n + ":")

#Team 2

c2 = input("Team 2: ")
man_t2 = input("Enter Manager for Team 1: ")
sub1_t2 = input("Enter Substitute 1 for Team 2: ")
sub2_t2 = input("Enter Substitute 2 for Team 2: ")
sub3_t2 = input("Enter Substitute 3 for Team 2: ")
sub4_t2 = input("Enter Substitute 4 for Team 2: ")
sub5_t2 = input("Enter Substitute 5 for Team 2: ")
sub6_t2 = input("Enter Substitute 6 for Team 2: ")
sub7_t2 = input("Enter Substitute 7 for Team 2: ")
form_t2 = input("Enter Formation; 1343 or 1442 : ")

#Team 2 Players 10

p1_t2_n = input("Enter Name for Player 1 on " + c2 + ":")
p1_t2_p = input("Enter Position for " + p1_t2_n +":")
p1_t2_c = input("Enter Country for " + p1_t2_n + ":")
p1_t2_j = input("Enter Jersey Number for " + p1_t2_n + ":")

p2_t2_n = input("Enter Name for Player 2 on " + c2 + ":")
p2_t2_p = input("Enter Position for " + p2_t2_n +":")
p2_t2_c = input("Enter Country for " + p2_t2_n + ":")
p2_t2_j = input("Enter Jersey Number for " + p2_t2_n + ":")

p3_t2_n = input("Enter Name for Player 3 on " + c2 + ":")
p3_t2_p = input("Enter Position for " + p3_t2_n +":")
p3_t2_c = input("Enter Country for " + p3_t2_n + ":")
p3_t2_j = input("Enter Jersey Number for " + p3_t2_n + ":")

p4_t2_n = input("Enter Name for Player 4 on " + c2 + ":")
p4_t2_p = input("Enter Position for " + p4_t2_n +":")
p4_t2_c = input("Enter Country for " + p4_t2_n + ":")
p4_t2_j = input("Enter Jersey Number for " + p4_t2_n + ":")

p5_t2_n = input("Enter Name for Player 5 on " + c2 + ":")
p5_t2_p = input("Enter Position for " + p5_t2_n +":")
p5_t2_c = input("Enter Country for " + p5_t2_n + ":")
p5_t2_j = input("Enter Jersey Number for " + p5_t2_n + ":")

p6_t2_n = input("Enter Name for Player 6 on " + c2 + ":")
p6_t2_p = input("Enter Position for " + p6_t2_n +":")
p6_t2_c = input("Enter Country for " + p6_t2_n + ":")
p6_t2_j = input("Enter Jersey Number for " + p6_t2_n + ":")

p7_t2_n = input("Enter Name for Player 7 on " + c2 + ":")
p7_t2_p = input("Enter Position for " + p7_t2_n +":")
p7_t2_c = input("Enter Country for " + p7_t2_n + ":")
p7_t2_j = input("Enter Jersey Number for " + p7_t2_n + ":")

p8_t2_n = input("Enter Name for Player 8 on " + c2 + ":")
p8_t2_p = input("Enter Position for " + p8_t2_n +":")
p8_t2_c = input("Enter Country for " + p8_t2_n + ":")
p8_t2_j = input("Enter Jersey Number for " + p8_t2_n + ":")

p9_t2_n = input("Enter Name for Player 9 on " + c2 + ":")
p9_t2_p = input("Enter Position for " + p9_t2_n +":")
p9_t2_c = input("Enter Country for " + p9_t2_n + ":")
p9_t2_j = input("Enter Jersey Number for " + p9_t2_n + ":")

p10_t2_n = input("Enter Name for Player 10 on " + c2 + ":")
p10_t2_p = input("Enter Position for " + p10_t2_n +":")
p10_t2_c = input("Enter Country for " + p10_t2_n + ":")
p10_t2_j = input("Enter Jersey Number for " + p10_t2_n + ":")

#Print Statements
print(" ")
print(" ")

if int(form_t1) == 1442:
    print("Formation for Team ", c1)
    print("* * * * * * *")
    print("*     X     *")
    print("* X X   X X *")
    print("* X X   X X *")
    print("*    X X    *")
    print("* * * * * * *")
    
else:
    print("Formation for Team ", c1)
    print("* * * * * * *")
    print("*     X     *")
    print("*  X  X  X  *")
    print("* X  X X  X *")
    print("*  X  X  X  *")
    print("* * * * * * *")
    
if int(form_t2) == 1442:
    print("Formation for Team ", c1)
    print("* * * * * * *")
    print("*     X     *")
    print("* X X   X X *")
    print("* X X   X X *")
    print("*    X X    *")
    print("* * * * * * *")
    
else:
    print("Formation for Team ", c1)
    print("* * * * * * *")
    print("*     X     *")
    print("*  X  X  X  *")
    print("* X  X X  X *")
    print("*  X  X  X  *")
    print("* * * * * * *")
    
print(" BLUE 0430 - 0500 ") 
print(" 7 passes ball to 20 ")
print(" 20 passes ball to 12 ")
print(" 12 passes ball to 7 ")
print(" 7 shoots to goal ")
print(" Ball enters goal ")

print("")
print(" BLACK 0600 - 0630")
print(" 11 recieves ball ")
print(" 11 shoots to goal ")
print(" Ball reflects off top goal")
print(" 16 ball out of play")
# Out:
# Team 1:  Everton
# Enter Manager for Team 1:  Carlo Ancelotti
# Enter Substitute 1 for Team 1:  Jonas Lossl
# Enter Substitute 2 for Team 1:  Leighton Baines
# Enter Substitute 3 for Team 1:  Fabian Delph
# Enter Substitute 4 for Team 1:  Yerry Mina
# Enter Substitute 5 for Team 1:  Morgan Schneiderlin
# Enter Substitute 6 for Team 1:  Seamus Coleman
# Enter Substitute 7 for Team 1:  Moise Kean
# Enter Formation; 1343 or 1442 :  1442
# Enter Name for Player 1 on Everton: Jordan Pickford
# Enter Position for Jordan Pickford: Goalie
# Enter Country for Jordan Pickford: England
# Enter Jersey Number for Jordan Pickford: 1
# Enter Name for Player 2 on Everton: Djibril Sidibe
# Enter Position for Djibril Sidibe: Right Defense
# Enter Country for Djibril Sidibe: France
# Enter Jersey Number for Djibril Sidibe: 19
# Enter Name for Player 3 on Everton: Michael Keane
# Enter Position for Michael Keane: Righ Center Defense
# Enter Country for Michael Keane: England
# ...
